# %%
import pandas as pd

# %%
#Importar archivos en Windows

datos = pd.read_csv("C:\\Users\\Mateo Parrado\\Desktop\\Python Curso\\DatosDemograficos.csv")

# %%
datos
# Out:
#           Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                   Aruba            ABW             10.244
# 1             Afghanistan            AFG             35.253
# 2                  Angola            AGO             45.985
# 3                 Albania            ALB             12.877
# 4    United Arab Emirates            ARE             11.044
# ..                    ...            ...                ...
# 190           Yemen, Rep.            YEM             32.947
# 191          South Africa            ZAF             20.850
# 192      Congo, Dem. Rep.            COD             42.394
# 193                Zambia            ZMB             40.471
# 194              Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# 0                    78.9        Ingreso alto
# 1                     5.9        Ingreso bajo
# 2                    19.1  Ingreso medio alto
# 3                    57.2  Ingreso medio alto
# ...

# %%
#Metodo2: Cambiando el Working Directory

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\Mateo Parrado\Desktop\Python Curso

# %%
#Explorando los datos importados

# %%
#NUmero de filas
len(datos) #195 filas (trazabilidad)
# Out:
# 195

# %%
#Ver las Columnas
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
# ver el numero de columnas
len(datos.columns)
# Out:
# 5

# %%
#Ver filas superiores
datos.head(10)
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
# 5             Argentina            ARG             17.716
# 6               Armenia            ARM             13.308
# 7   Antigua and Barbuda            ATG             16.447
# 8             Australia            AUS             13.200
# 9               Austria            AUT              9.400
#
#    Usuarios de Internet   Grupo de ingresos
# 0               78.9000        Ingreso alto
# 1                5.9000        Ingreso bajo
# 2               19.1000  Ingreso medio alto
# 3               57.2000  Ingreso medio alto
# 4               88.0000        Ingreso alto
# 5               59.9000        Ingreso alto
# ...

# %%
#Ver filas inferiores
datos.tail(12)
# Out:
#                     Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 183  St. Vincent and the Grenadines            VCT             16.306
# 184                   Venezuela, RB            VEN             19.842
# 185           Virgin Islands (U.S.)            VIR             10.700
# 186                         Vietnam            VNM             15.537
# 187                         Vanuatu            VUT             26.739
# 188              West Bank and Gaza            PSE             30.394
# 189                           Samoa            WSM             26.172
# 190                     Yemen, Rep.            YEM             32.947
# 191                    South Africa            ZAF             20.850
# 192                Congo, Dem. Rep.            COD             42.394
# 193                          Zambia            ZMB             40.471
# 194                        Zimbabwe            ZWE             35.715
#
#      Usuarios de Internet   Grupo de ingresos
# ...

# %%
#Información de las columnas
datos.info() #Como la función str de R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nombre del Pais       195 non-null    object
#  1   Codigo de Pais        195 non-null    object
#  2   Tasa de Natalidad     195 non-null    float64
#  3   Usuarios de Internet  195 non-null    float64
#  4   Grupo de ingresos     195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#Obtener estadisticas de las columnas
datos.describe() #Como summary en R
# Out:
#        Tasa de Natalidad  Usuarios de Internet
# count         195.000000            195.000000
# mean           21.469928             42.076471
# std            10.605467             29.030788
# min             7.900000              0.900000
# 25%            12.120500             14.520000
# 50%            19.680000             41.000000
# 75%            29.759500             66.225000
# max            49.661000             96.546800

# %%
datos.describe().transpose()
# Out:
#                       count       mean        std  min      25%    50%  \
# Tasa de Natalidad     195.0  21.469928  10.605467  7.9  12.1205  19.68
# Usuarios de Internet  195.0  42.076471  29.030788  0.9  14.5200  41.00
#
#                           75%      max
# Tasa de Natalidad     29.7595  49.6610
# Usuarios de Internet  66.2250  96.5468

# %%
#Cambiandole nombre a las columnas de un dataframe
datos.head()
# Out:
#         Nombre del Pais Codigo de Pais  Tasa de Natalidad  \
# 0                 Aruba            ABW             10.244
# 1           Afghanistan            AFG             35.253
# 2                Angola            AGO             45.985
# 3               Albania            ALB             12.877
# 4  United Arab Emirates            ARE             11.044
#
#    Usuarios de Internet   Grupo de ingresos
# 0                  78.9        Ingreso alto
# 1                   5.9        Ingreso bajo
# 2                  19.1  Ingreso medio alto
# 3                  57.2  Ingreso medio alto
# 4                  88.0        Ingreso alto

# %%
datos.columns
# Out:
# Index(['Nombre del Pais', 'Codigo de Pais', 'Tasa de Natalidad',
#        'Usuarios de Internet', 'Grupo de ingresos'],
#       dtype='object')

# %%
datos.columns =["a","b","c","d","e"]
datos.head()
# Out:
#                       a    b       c     d                   e
# 0                 Aruba  ABW  10.244  78.9        Ingreso alto
# 1           Afghanistan  AFG  35.253   5.9        Ingreso bajo
# 2                Angola  AGO  45.985  19.1  Ingreso medio alto
# 3               Albania  ALB  12.877  57.2  Ingreso medio alto
# 4  United Arab Emirates  ARE  11.044  88.0        Ingreso alto

# %%
datos.columns =["NombrePais","CodigoPais","TasaNatalidad","UsuariosInternet","GrupoIngresos"]
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#Subconjuntos de DataFrames en Pandas

# %%
#Subconjuntos por Filas
datos[21:26]
# Out:
#    NombrePais CodigoPais  TasaNatalidad  UsuariosInternet       GrupoIngresos
# 21     Belize        BLZ         23.092             33.60  Ingreso medio alto
# 22    Bermuda        BMU         10.400             95.30        Ingreso alto
# 23    Bolivia        BOL         24.236             36.94  Ingreso medio bajo
# 24     Brazil        BRA         14.931             51.04  Ingreso medio alto
# 25   Barbados        BRB         12.188             73.00        Ingreso alto

# %%
datos[::-1]
# Out:
#                NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 194              Zimbabwe        ZWE         35.715              18.5
# 193                Zambia        ZMB         40.471              15.4
# 192      Congo, Dem. Rep.        COD         42.394               2.2
# 191          South Africa        ZAF         20.850              46.5
# 190           Yemen, Rep.        YEM         32.947              20.0
# ..                    ...        ...            ...               ...
# 4    United Arab Emirates        ARE         11.044              88.0
# 3                 Albania        ALB         12.877              57.2
# 2                  Angola        AGO         45.985              19.1
# 1             Afghanistan        AFG         35.253               5.9
# 0                   Aruba        ABW         10.244              78.9
#
#           GrupoIngresos
# 194        Ingreso bajo
# 193  Ingreso medio bajo
# 192        Ingreso bajo
# 191  Ingreso medio alto
# ...

# %%
datos[::20]
# Out:
#      NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0         Aruba        ABW         10.244           78.9000
# 20      Belarus        BLR         12.500           54.1700
# 40   Costa Rica        CRI         15.022           45.9600
# 60        Gabon        GAB         30.555            9.2000
# 80        India        IND         20.291           15.1000
# 100       Libya        LBY         21.425           16.5000
# 120  Mozambique        MOZ         39.705            5.4000
# 140      Poland        POL          9.600           62.8492
# 160    Suriname        SUR         18.455           37.4000
# 180     Uruguay        URY         14.374           57.6900
#
#           GrupoIngresos
# 0          Ingreso alto
# 20   Ingreso medio alto
# 40   Ingreso medio alto
# 60   Ingreso medio alto
# 80   Ingreso medio bajo
# 100  Ingreso medio alto
# 120        Ingreso bajo
# 140        Ingreso alto
# 160  Ingreso medio alto
# 180        Ingreso alto

# %%
#Subconjuntos por Columnas
datos["NombrePais"]
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: NombrePais, Length: 195, dtype: object

# %%
datos["NombrePais"].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: NombrePais, dtype: object

# %%
datos[["NombrePais","TasaNatalidad"]].head() #por columnas se presenta como dataframe, por filas no
# Out:
#              NombrePais  TasaNatalidad
# 0                 Aruba         10.244
# 1           Afghanistan         35.253
# 2                Angola         45.985
# 3               Albania         12.877
# 4  United Arab Emirates         11.044

# %%
#acceso rapido
datos["TasaNatalidad"]
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: TasaNatalidad, Length: 195, dtype: float64

# %%
datos.TasaNatalidad #Para que funcione el nombre de la columna debe ser una sola palabra
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: TasaNatalidad, Length: 195, dtype: float64

# %%
#Subconjuntos por filas y Columnas

datos[4:8][["NombrePais","TasaNatalidad"]]
# Out:
#              NombrePais  TasaNatalidad
# 4  United Arab Emirates         11.044
# 5             Argentina         17.716
# 6               Armenia         13.308
# 7   Antigua and Barbuda         16.447

# %%
datos[["NombrePais","TasaNatalidad"]][4:8]
# Out:
#              NombrePais  TasaNatalidad
# 4  United Arab Emirates         11.044
# 5             Argentina         17.716
# 6               Armenia         13.308
# 7   Antigua and Barbuda         16.447

# %%
#Operaciones basicas con Data Frame 
#Operaciones Matematicas

resultado = datos.TasaNatalidad * datos.UsuariosInternet

# %%
resultado.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
#AgregarColumna al DataFrame
datos["MiCalculo"] = datos.TasaNatalidad * datos.UsuariosInternet # En Python la columna agregada debe completar los datos (195 registros en este caso)

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos  MiCalculo
# 0        Ingreso alto   808.2516
# 1        Ingreso bajo   207.9927
# 2  Ingreso medio alto   878.3135
# 3  Ingreso medio alto   736.5644
# 4        Ingreso alto   971.8720

# %%
#Removiendo Columna
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos  MiCalculo
# 0        Ingreso alto   808.2516
# 1        Ingreso bajo   207.9927
# 2  Ingreso medio alto   878.3135
# 3  Ingreso medio alto   736.5644
# 4        Ingreso alto   971.8720

# %%
datos= datos.drop("MiCalculo",axis= 1) #Sobreescribir el dataframe con uno nuevo para que eliminar la columna sea efectiva
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
#Filtrando un DataFrame   
#El filtrado se aplica a las filas

# %%
datos.UsuariosInternet < 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: UsuariosInternet, Length: 195, dtype: bool

# %%
filtro = datos.UsuariosInternet < 2 #Se crea un objeto llamado filtro, el cual se le pasa por parametro al dataframe

# %%
datos[filtro] # Muestra los datos filtrados ( los que dieron True en la condicion evaluada de usuarios < 2)
# Out:
#        NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 11        Burundi        BDI         44.151               1.3
# 52        Eritrea        ERI         34.800               0.9
# 55       Ethiopia        ETH         32.925               1.9
# 64         Guinea        GIN         37.337               1.6
# 117       Myanmar        MMR         18.119               1.6
# 127         Niger        NER         49.661               1.7
# 154  Sierra Leone        SLE         36.729               1.7
# 156       Somalia        SOM         43.891               1.5
# 172   Timor-Leste        TLS         35.755               1.1
#
#           GrupoIngresos
# 11         Ingreso bajo
# 52         Ingreso bajo
# 55         Ingreso bajo
# 64         Ingreso bajo
# 117  Ingreso medio bajo
# 127        Ingreso bajo
# 154        Ingreso bajo
# 156        Ingreso bajo
# 172  Ingreso medio bajo

# %%
filtro2 = datos.TasaNatalidad > 40

# %%
datos[filtro2]
# Out:
#            NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 2              Angola        AGO         45.985              19.1
# 11            Burundi        BDI         44.151               1.3
# 14       Burkina Faso        BFA         40.551               9.1
# 65        Gambia, The        GMB         42.525              14.0
# 115              Mali        MLI         44.138               3.5
# 127             Niger        NER         49.661               1.7
# 128           Nigeria        NGA         40.045              38.0
# 156           Somalia        SOM         43.891               1.5
# 167              Chad        TCD         45.745               2.3
# 178            Uganda        UGA         43.474              16.2
# 192  Congo, Dem. Rep.        COD         42.394               2.2
# 193            Zambia        ZMB         40.471              15.4
#
#           GrupoIngresos
# 2    Ingreso medio alto
# 11         Ingreso bajo
# 14         Ingreso bajo
# ...

# %%
filtro & filtro2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
datos[filtro & filtro2]
# Out:
#     NombrePais CodigoPais  TasaNatalidad  UsuariosInternet GrupoIngresos
# 11     Burundi        BDI         44.151               1.3  Ingreso bajo
# 127      Niger        NER         49.661               1.7  Ingreso bajo
# 156    Somalia        SOM         43.891               1.5  Ingreso bajo

# %%
#para cuando la colmuna tiene valores categoricos
datos.GrupoIngresos.unique()
# Out:
# array(['Ingreso alto', 'Ingreso bajo', 'Ingreso medio alto',
#        'Ingreso medio bajo'], dtype=object)

# %%
filtro3 = datos.GrupoIngresos == "Ingreso alto"
filtro3
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: GrupoIngresos, Length: 195, dtype: bool

# %%
datos[filtro3]
# Out:
#                 NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                    Aruba        ABW         10.244             78.90
# 4     United Arab Emirates        ARE         11.044             88.00
# 5                Argentina        ARG         17.716             59.90
# 7      Antigua and Barbuda        ATG         16.447             63.40
# 8                Australia        AUS         13.200             83.00
# ..                     ...        ...            ...               ...
# 174    Trinidad and Tobago        TTO         14.590             63.80
# 180                Uruguay        URY         14.374             57.69
# 181          United States        USA         12.500             84.20
# 184          Venezuela, RB        VEN         19.842             54.90
# 185  Virgin Islands (U.S.)        VIR         10.700             45.30
#
#     GrupoIngresos
# 0    Ingreso alto
# 4    Ingreso alto
# 5    Ingreso alto
# 7    Ingreso alto
# ...

# %%
filtro4 = datos.NombrePais=="Malta"
filtro4
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: NombrePais, Length: 195, dtype: bool

# %%
datos[filtro4]
# Out:
#     NombrePais CodigoPais  TasaNatalidad  UsuariosInternet GrupoIngresos
# 116      Malta        MLT            9.5           68.9138  Ingreso alto

# %%
#Acceso a Elementos Individuales (parecido a como se hace en matrices)

# %%
.at #Para etiquetas ( busca por la etiqueta)
.iat #ubicación con numeros enteros ( Busca por el indice)

# %%
datos.iat[3,4]
# Out:
# 'Ingreso medio alto'

# %%
datos.iat[0,1]
# Out:
# 'ABW'

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
datos.at[2, "TasaNatalidad"]
# Out:
# 45.985

# %%
#Introducción a Seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["figure.figsize"] = 8,4

# %%
datos.head()
# Out:
#              NombrePais CodigoPais  TasaNatalidad  UsuariosInternet  \
# 0                 Aruba        ABW         10.244              78.9
# 1           Afghanistan        AFG         35.253               5.9
# 2                Angola        AGO         45.985              19.1
# 3               Albania        ALB         12.877              57.2
# 4  United Arab Emirates        ARE         11.044              88.0
#
#         GrupoIngresos
# 0        Ingreso alto
# 1        Ingreso bajo
# 2  Ingreso medio alto
# 3  Ingreso medio alto
# 4        Ingreso alto

# %%
vis1 = sns.distplot(datos["UsuariosInternet"])
# Out:
# C:\Users\Mateo Parrado\AppData\Local\Temp\ipykernel_16612\1782718409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1 = sns.distplot(datos["UsuariosInternet"])

# %%
vis1 = sns.distplot(datos["UsuariosInternet"],bins= 30)
# Out:
# C:\Users\Mateo Parrado\AppData\Local\Temp\ipykernel_16612\2299015881.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1 = sns.distplot(datos["UsuariosInternet"],bins= 30)

# %%
vis2= sns.boxplot(data= datos, x="GrupoIngresos",y= "TasaNatalidad")

# %%
#Seaborn Gallery

# %%
vis3= sns.lmplot( x= "UsuariosInternet", y= "TasaNatalidad",data= datos, fit_reg= False, hue= "GrupoIngresos")
# Out:
# C:\Users\Mateo Parrado\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
vis3= sns.lmplot( x= "UsuariosInternet", y= "TasaNatalidad",data= datos, fit_reg= False, hue= "GrupoIngresos",scatter_kws={"s":100})
# Out:
# C:\Users\Mateo Parrado\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
